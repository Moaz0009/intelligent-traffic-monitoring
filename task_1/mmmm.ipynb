# %%
import cv2

video_path = "C:/Users/Two Star/Desktop/AI Capsule/Intelligent Traffic & Parking Monitoring System/Vehicle Dataset Sample 3.mp4"   

cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print(" Error: Could not open video")
    exit()

while True:
    ret, frame = cap.read()

    if not ret:
        print("Video ended")
        break

    cv2.imshow("Video", frame)

    
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

video_path = "C:/Users/Two Star/Desktop/AI Capsule/Intelligent Traffic & Parking Monitoring System/Vehicle Dataset Sample 3.mp4"
cap = cv2.VideoCapture(video_path)


line_y = 400


count = 0
counted_ids = set()

while True:
    ret, frame = cap.read()
    if not ret:
        break

    
    results = model.track(
        frame,
        conf=0.7,
        classes=[2, 3, 5, 7],  # car, motorcycle, bus, truck
        persist=True
    )

    
    annotated_frame = results[0].plot()

    
    if results[0].boxes.id is not None:
        for box in results[0].boxes:
            track_id = int(box.id[0])

            x1, y1, x2, y2 = box.xyxy[0]
            cx = int((x1 + x2) / 2)
            cy = int((y1 + y2) / 2)

            
            cv2.circle(annotated_frame, (cx, cy), 4, (255, 0, 0), -1)

            
            if track_id not in counted_ids and cy > line_y:
                count += 1
                counted_ids.add(track_id)

    
    cv2.line(
        annotated_frame,
        (0, line_y),
        (annotated_frame.shape[1], line_y),
        (0, 0, 255),
        2
    )

    
    cv2.putText(
        annotated_frame,
        f"Count: {count}",
        (50, 50),
        cv2.FONT_HERSHEY_SIMPLEX,
        1,
        (0, 255, 0),
        2
    )

    cv2.imshow("Vehicle Counting", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 car, 42.9ms
# Speed: 1.8ms preprocess, 42.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 36.2ms
# Speed: 1.7ms preprocess, 36.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 28.3ms
# Speed: 1.2ms preprocess, 28.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 30.7ms
# Speed: 1.4ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 32.1ms
# Speed: 1.5ms preprocess, 32.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 29.0ms
# Speed: 2.3ms preprocess, 29.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.8ms
# Speed: 2.3ms preprocess, 32.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 29.9ms
# ...
